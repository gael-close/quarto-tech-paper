# %% [markdown]
# # Standalone notebook
#
# Example: Exploratory data analysis

# %%
# Autoreload
# %reload_ext autoreload
# %autoreload 2

# Generic init code
from {{cookiecutter.package_name}}.myinit import *
from {{cookiecutter.package_name}}.dataset import *
from {{cookiecutter.package_name}}.plots import *

# Optional checks
print(sys.executable)
my_sineplot();

# Specific library for summarizing dataframe
from summarytools import dfSummary

# %% [markdown]
# ## Dataset overview

# %%
df=load_data()   
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  model-year
# 0  18.0          8         307.0       130.0    3504          12.0          70
# 1  15.0          8         350.0       165.0    3693          11.5          70
# 2  18.0          8         318.0       150.0    3436          11.0          70
# 3  16.0          8         304.0       150.0    3433          12.0          70
# 4  17.0          8         302.0       140.0    3449          10.5          70

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_e51ec thead>tr>th {
#   text-align: left;
# }
# #T_e51ec_row0_col0, #T_e51ec_row1_col0, #T_e51ec_row2_col0, #T_e51ec_row3_col0, #T_e51ec_row4_col0, #T_e51ec_row5_col0, #T_e51ec_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_e51ec_row0_col1, #T_e51ec_row1_col1, #T_e51ec_row2_col1, #T_e51ec_row3_col1, #T_e51ec_row4_col1, #T_e51ec_row5_col1, #T_e51ec_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_e51ec_row0_col2, #T_e51ec_row1_col2, #T_e51ec_row2_col2, #T_e51ec_row3_col2, #T_e51ec_row4_col2, #T_e51ec_row5_col2, #T_e51ec_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_e51ec_row0_col3, #T_e51ec_row1_col3, #T_e51ec_row2_col3, #T_e51ec_row3_col3, #T_e51ec_row4_col3, #T_e51ec_row5_col3, #T_e51ec_row6_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_e51ec_row0_col4, #T_e51ec_row1_col4, #T_e51ec_row2_col4, #T_e51ec_row3_col4, #T_e51ec_row4_col4, #T_e51ec_row5_col4, #T_e51ec_row6_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_e51ec_row0_col5, #T_e51ec_row1_col5, #T_e51ec_row2_col5, #T_e51ec_row3_col5, #T_e51ec_row4_col5, #T_e51ec_row5_col5, #T_e51ec_row6_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_e51ec">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 398 x 7<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_e51ec_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_e51ec_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_e51ec_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_e51ec_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_e51ec_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_e51ec_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e51ec_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e51ec_row0_col1" class="data row0 col1" ><strong>mpg</strong><br>[float64]</td>
#       <td id="T_e51ec_row0_col2" class="data row0 col2" >Mean (sd) : 23.5 (7.8)<br>min < med < max:<br>9.0 < 23.0 < 46.6<br>IQR (CV) : 11.5 (3.0)</td>
#       <td id="T_e51ec_row0_col3" class="data row0 col3" >129 distinct values</td>
#       <td id="T_e51ec_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_e51ec_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e51ec_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e51ec_row1_col1" class="data row1 col1" ><strong>cylinders</strong><br>[int64]</td>
#       <td id="T_e51ec_row1_col2" class="data row1 col2" >1. 4<br>2. 8<br>3. 6<br>4. 3<br>5. 5</td>
#       <td id="T_e51ec_row1_col3" class="data row1 col3" >204 (51.3%)<br>103 (25.9%)<br>84 (21.1%)<br>4 (1.0%)<br>3 (0.8%)</td>
#       <td id="T_e51ec_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_e51ec_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e51ec_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e51ec_row2_col1" class="data row2 col1" ><strong>displacement</strong><br>[float64]</td>
#       <td id="T_e51ec_row2_col2" class="data row2 col2" >Mean (sd) : 193.4 (104.3)<br>min < med < max:<br>68.0 < 148.5 < 455.0<br>IQR (CV) : 157.8 (1.9)</td>
#       <td id="T_e51ec_row2_col3" class="data row2 col3" >82 distinct values</td>
#       <td id="T_e51ec_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_e51ec_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e51ec_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e51ec_row3_col1" class="data row3 col1" ><strong>horsepower</strong><br>[float64]</td>
#       <td id="T_e51ec_row3_col2" class="data row3 col2" >Mean (sd) : 104.2 (38.4)<br>min < med < max:<br>46.0 < 92.0 < 230.0<br>IQR (CV) : 50.0 (2.7)</td>
#       <td id="T_e51ec_row3_col3" class="data row3 col3" >93 distinct values</td>
#       <td id="T_e51ec_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_e51ec_row3_col5" class="data row3 col5" >2<br>(0.5%)</td>
#     </tr>
#     <tr>
#       <td id="T_e51ec_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e51ec_row4_col1" class="data row4 col1" ><strong>weight</strong><br>[int64]</td>
#       <td id="T_e51ec_row4_col2" class="data row4 col2" >Mean (sd) : 2970.4 (846.8)<br>min < med < max:<br>1613.0 < 2803.5 < 5140.0<br>IQR (CV) : 1384.2 (3.5)</td>
#       <td id="T_e51ec_row4_col3" class="data row4 col3" >351 distinct values</td>
#       <td id="T_e51ec_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_e51ec_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e51ec_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_e51ec_row5_col1" class="data row5 col1" ><strong>acceleration</strong><br>[float64]</td>
#       <td id="T_e51ec_row5_col2" class="data row5 col2" >Mean (sd) : 15.6 (2.8)<br>min < med < max:<br>8.0 < 15.5 < 24.8<br>IQR (CV) : 3.3 (5.6)</td>
#       <td id="T_e51ec_row5_col3" class="data row5 col3" >95 distinct values</td>
#       <td id="T_e51ec_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_e51ec_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e51ec_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_e51ec_row6_col1" class="data row6 col1" ><strong>model-year</strong><br>[int64]</td>
#       <td id="T_e51ec_row6_col2" class="data row6 col2" >Mean (sd) : 76.0 (3.7)<br>min < med < max:<br>70.0 < 76.0 < 82.0<br>IQR (CV) : 6.0 (20.6)</td>
#       <td id="T_e51ec_row6_col3" class="data row6 col3" >13 distinct values</td>
#       <td id="T_e51ec_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_e51ec_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Exploratory Data Analysis
#
# You might use https://github.com/Kanaries/pygwalker to quickly visualize your data.

# %% [markdown]
# ### Plots

# %%
#| label: fig-joint-plot
#| fig-cap: "This figure was generated in a support notebook. \
#|  Alternatively, it can be generated on-the-fly in the paper itself."

ax=plot_joint(df);
ax.fig.set_size_inches(3.5,1.5)

# %% [markdown]
# ## Scratch pad

# %%
n = 50; 
# %run -i support.py
# Out:
# ic| 'Sampling ', n: 50
